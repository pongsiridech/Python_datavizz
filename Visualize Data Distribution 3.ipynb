# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
df = pd.read_excel('C:\\python_dataviz\\Python_datavizz\\income.xlsx', header =3)

# %%
df
# Out:
#          ภาค และจังหวัด                                         Unnamed: 1  \
# 0                   NaN                                                NaN
# 1                   NaN                                                NaN
# 2       ทั่วราชอาณาจักร                                                NaN
# 3              ตอนพิเศษ                                                NaN
# 4         กรุงเทพมหานคร                                                NaN
# 5           สมุทรปราการ                                                NaN
# 6               นนทบุรี                                                NaN
# 7              ปทุมธานี                                                NaN
# 8               ภาคกลาง                                                NaN
# 9       พระนครศรีอยุธยา                                                NaN
# 10              อ่างทอง                                                NaN
# 11               ลพบุรี                                                NaN
# 12            สิงห์บุรี                                                NaN
# 13               ชัยนาท                                                NaN
# 14              สระบุรี                                                NaN
# 15               ชลบุรี                                                NaN
# 16                ระยอง                                                NaN
# 17             จันทบุรี                                                NaN
# 18                 ตราด                                                NaN
# 19           ฉะเชิงเทรา                                                NaN
# 20           ปราจีนบุรี                                                NaN
# 21              นครนายก                                                NaN
# 22              สระแก้ว                                                NaN
# 23              ราชบุรี                                                NaN
# 24            กาญจนบุรี                                                NaN
# 25           สุพรรณบุรี                                                NaN
# 26               นครปฐม                                                NaN
# 27            สมุทรสาคร                                                NaN
# 28          สมุทรสงคราม                                                NaN
# 29             เพชรบุรี                                                NaN
# ..                  ...                                                ...
# 59          หนองบัวลำภู                                                NaN
# 60              ขอนแก่น                                                NaN
# 61             อุดรธานี                                                NaN
# 62                  เลย                                                NaN
# 63              หนองคาย                                                NaN
# 64            มหาสารคาม                                                NaN
# 65             ร้อยเอ็ด                                                NaN
# 66            กาฬสินธุ์                                                NaN
# 67               สกลนคร                                                NaN
# 68               นครพนม                                                NaN
# 69             มุกดาหาร                                                NaN
# 70               ภาคใต้                                                NaN
# 71        นครศรีธรรมราช                                                NaN
# 72               กระบี่                                                NaN
# 73                พังงา                                                NaN
# 74               ภูเก็ต                                                NaN
# 75         สุราษฎร์ธานี                                                NaN
# 76                ระนอง                                                NaN
# 77                ชุมพร                                                NaN
# 78                สงขลา                                                NaN
# 79                 สตูล                                                NaN
# 80                 ตรัง                                                NaN
# 81               พัทลุง                                                NaN
# 82              ปัตตานี                                                NaN
# 83                 ยะลา                                                NaN
# 84             นราธิวาส                                                NaN
# 85                  NaN                                                NaN
# 86                  NaN                                                NaN
# 87               ที่มา:  การสำรวจภาวะเศรษฐกิจและสังคมของครัวเรือน  สำนั...
# 88              Source:  The Household Socio - Economic Survey, Nationa...
#
#        2541     2543     2545     2547     2549     2550     2552     2554  \
# 0    1998.0   2000.0   2002.0   2004.0   2006.0   2007.0   2009.0   2011.0
# 1       NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2   12492.0  12150.0  13736.0  14963.0  17787.0  18660.0  20904.0  23235.9
# 3   24929.0  25242.0  28239.0  28135.0  33088.0  35007.0  37732.0  41630.6
# 4   26054.0  26909.0  29589.0  29843.0  36658.0  39020.0  42380.0  48951.0
# 5   18100.0  15745.0  19680.0  19946.0  20382.0  21302.0  23359.0  23797.9
# 6   24211.0  24566.0  29119.0  26658.0  31152.0  32743.0  34626.0  35119.7
# 7   21793.0  19282.0  22838.0  21530.0  25143.0  26107.0  26686.0  21615.5
# 8   12643.0  13012.0  14128.0  16355.0  19279.0  18932.0  20960.0  20821.8
# 9   12918.0  14904.0  13319.0  14980.0  19676.0  21676.0  25820.0  22301.7
# 83  22483.1  15583.800000                          Yala
# 84  16772.8  19889.600000                    Narathiwat
# 85      NaN           NaN                           NaN
# 86      NaN           NaN                           NaN
# 87      NaN           NaN                           NaN
# 88      NaN           NaN                           NaN
#
# [89 rows x 13 columns]

# %%
greaterbangkok = df.iloc[4:8,:]
greaterbangkok
# Out:
#       ภาค และจังหวัด Unnamed: 1     2541     2543     2545     2547     2549  \
# 4      กรุงเทพมหานคร        NaN  26054.0  26909.0  29589.0  29843.0  36658.0
# 5        สมุทรปราการ        NaN  18100.0  15745.0  19680.0  19946.0  20382.0
# 6            นนทบุรี        NaN  24211.0  24566.0  29119.0  26658.0  31152.0
# 7           ปทุมธานี        NaN  21793.0  19282.0  22838.0  21530.0  25143.0
#
#       2550     2552     2554     2556     2558 Region and province
# 4  39020.0  42380.0  48951.0  49190.8  45571.7             Bangkok
# 5  21302.0  23359.0  23797.9  29575.3  25457.2        Samut Prakan
# 6  32743.0  34626.0  35119.7  30663.6  36884.0          Nonthaburi
# 7  26107.0  26686.0  21615.5  33461.3  41056.9        Pathum Thani

# %% [markdown]
# # Barchart (กราฟแท่ง)

# %% [markdown]
# ## สร้างกราฟแท่งเปรียบเทียบรายได้ในปี 2541 ของจังหวัดกรุงเทพและปริมณฑล

# %%
plt.bar([1,2,3,4],greaterbangkok.iloc[:,2])
plt.title('Barchart comparing average monthly income of provinces in Greater Bangkok in 2541')
plt.xlabel('provinces')
plt.ylabel('income Baht/Month/Household')
# Out:
# Text(0, 0.5, 'income Baht/Month/Household')

# %% [markdown]
# # add tick label

# %%
plt.bar([1,2,3,4],greaterbangkok.iloc[:,2],tick_label=greaterbangkok.iloc[:,-1])
plt.title('Barchart comparing average monthly income of provinces in Greater Bangkok in 2541')
plt.xlabel('provinces')
plt.ylabel('income Baht/Month/Household')
# Out:
# Text(0, 0.5, 'income Baht/Month/Household')

# %% [markdown]
# ## compare different years

# %%
plt.bar([1-(0.35/2),2-(0.35/2),3-(0.35/2),4-(0.35/2)],greaterbangkok.iloc[:,-2],width=0.35,tick_label=greaterbangkok.iloc[:,-1],color = 'r' , label='2558')
plt.bar([1+(0.35/2),2+(0.35/2),3+(0.35/2),4+(0.35/2)],greaterbangkok.iloc[:,2],width=0.35,tick_label=greaterbangkok.iloc[:,-1],color = 'G' , label='2541')
plt.title('Barchart comparing average monthly income of provinces in Greater Bankok in 2541,2558')
plt.xlabel('provinces')
plt.legend()
plt.ylabel('income Baht/Month/Household')
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: MatplotlibDeprecationWarning: Support for uppercase single-letter colors is deprecated since Matplotlib 3.1 and will be removed in 3.3; please use lowercase instead.
# Text(0, 0.5, 'income Baht/Month/Household')

# %% [markdown]
# # Stacked Barchart

# %%
saledata = pd.DataFrame([{'North':20,'East':10,'West':90,'South':120},{'North':220,'East':20,'West':50,'South':90}])
saledata
# Out:
#    East  North  South  West
# 0    10     20    120    90
# 1    20    220     90    50

# %%
plt.bar([1,2],saledata.iloc[:,0],tick_label=['Company A','Company B'])
plt.bar([1,2],saledata.iloc[:,1],bottom=saledata.iloc[:,0],tick_label=['Company A','Company B'])
plt.bar([1,2],saledata.iloc[:,2],bottom=saledata.iloc[:,0]+saledata.iloc[:,1],tick_label=['Company A','Company B'])
plt.bar([1,2],saledata.iloc[:,3],bottom=saledata.iloc[:,0]+saledata.iloc[:,1]+saledata.iloc[:,2],tick_label=['Company A','Company B'])
# Out:
# <BarContainer object of 2 artists>
