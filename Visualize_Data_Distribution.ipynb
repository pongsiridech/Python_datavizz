# %%
from matplotlib import pyplot as plt

# %%
import pandas  as pd
import numpy as np
import matplotlib

# %%
iris = 'C:\\Users\\Admin\Downloads\\iris.data'
iris1 = pd.read_csv(iris,header=None) # header=None ใช้สำหรับไฟล์ที่ไม่มีหัวตาราง
iris1.head()
# Out:
#      0    1    2    3            4
# 0  5.1  3.5  1.4  0.2  Iris-setosa
# 1  4.9  3.0  1.4  0.2  Iris-setosa
# 2  4.7  3.2  1.3  0.2  Iris-setosa
# 3  4.6  3.1  1.5  0.2  Iris-setosa
# 4  5.0  3.6  1.4  0.2  Iris-setosa

# %%
setosa_np = iris1.iloc[:50,:-1].to_numpy()
setosa_np
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [4.6, 3.4, 1.4, 0.3],
#        [5. , 3.4, 1.5, 0.2],
#        [4.4, 2.9, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.4, 3.7, 1.5, 0.2],
#        [4.8, 3.4, 1.6, 0.2],
#        [4.8, 3. , 1.4, 0.1],
#        [4.3, 3. , 1.1, 0.1],
#        [5.8, 4. , 1.2, 0.2],
#        [5.7, 4.4, 1.5, 0.4],
#        [5.4, 3.9, 1.3, 0.4],
#        [5.1, 3.5, 1.4, 0.3],
#        [5.7, 3.8, 1.7, 0.3],
#        [5.1, 3.8, 1.5, 0.3],
#        [5.4, 3.4, 1.7, 0.2],
#        [5.1, 3.7, 1.5, 0.4],
#        [4.6, 3.6, 1. , 0.2],
#        [5.1, 3.3, 1.7, 0.5],
#        [4.8, 3.4, 1.9, 0.2],
#        [5. , 3. , 1.6, 0.2],
#        [5. , 3.4, 1.6, 0.4],
#        [5.2, 3.5, 1.5, 0.2],
#        [5.2, 3.4, 1.4, 0.2],
#        [4.7, 3.2, 1.6, 0.2],
#        [4.8, 3.1, 1.6, 0.2],
#        [5.4, 3.4, 1.5, 0.4],
# ...

# %%
plt.scatter(x, y, s=None, c=None, marker=None, cmap=None, norm=None, vmin=None, vmax=None, alpha=None,
                          linewidths=None, verts=None, edgecolors=None, *, plotnonfinite=False, data=None, **kwargs)

s คือ ขนาด
c,cmap คือ สี
marker คือ รูปแบบของจุด
# Out:
#   File "<ipython-input-12-3ea2e5bc5199>", line 2
#     linewidths=None, verts=None, edgecolors=None, *, plotnonfinite=False, data=None, **kwargs)
#                                                    ^
# SyntaxError: invalid syntax

# %%
plt.scatter(setosa_np[:,0],setosa_np[:,1])

# %% [markdown]
# # size

# %%
plt.scatter(setosa_np[:,0],setosa_np[:,1],s = 6)

# %%
plt.scatter(setosa_np[:,0],setosa_np[:,1],s = setosa_np[:,2])

# %%
plt.scatter(setosa_np[:,0],setosa_np[:,1],s = 10*setosa_np[:,2])

# %% [markdown]
# # Color

# %%
plt.scatter(setosa_np[:,0], setosa_np[:,1], s = 10*setosa_np[:,2], c='g') #CMYKRGB

# %%
print(f'max = {max(setosa_np[:,3])},min = {min(setosa_np[:,3])}')
# Out:
# max = 0.6,min = 0.1

# %%
colors = []
for i in setosa_np[:,3]:
    if i < 0.15:
        colors.append('b')
    elif i < 0.3:
        colors.append('g')
    elif i < 0.45:
        colors.append('y')
    else:
        colors.append('r')

# %%
colors
# Out:
# ['g',
#  'g',
#  'g',
#  'g',
#  'g',
#  'y',
#  'y',
#  'g',
#  'g',
#  'b',
#  'g',
#  'g',
#  'b',
#  'b',
#  'g',
#  'y',
#  'y',
#  'y',
#  'y',
#  'y',
#  'g',
#  'y',
#  'g',
#  'r',
#  'g',
#  'g',
#  'y',
#  'g',
#  'g',
#  'g',
#  'g',
#  'y',
#  'b',
#  'g',
#  'b',
#  'g',
#  'g',
#  'b',
#  'g',
#  'g',
#  'y',
#  'y',
#  'g',
#  'r',
#  'y',
#  'y',
#  'g',
#  'g',
#  'g',
#  'g']

# %%
plt.scatter(setosa_np[:,0], setosa_np[:,1], s = 20*setosa_np[:,2], c=colors)

# %%
plt.scatter(setosa_np[:,0], setosa_np[:,1], s = 20*setosa_np[:,2], c=setosa_np[:,3])

# %%
plt.scatter(setosa_np[:,0], setosa_np[:,1], s = 20*setosa_np[:,2], c=setosa_np[:,3],cmap = 'YlOrBr')

# %%
plt.scatter(setosa_np[:,0], setosa_np[:,1], s = 20*setosa_np[:,2], c=np.array([[1,0.5,1]])) # R =1 G =0.5 B =1

# %% [markdown]
# # marker

# %%
plt.scatter(setosa_np[:,0], setosa_np[:,1], s = 20*setosa_np[:,2], c=np.array([[1,0.5,1]]),marker='x')

# %% [markdown]
# # Visualize 2 data

# %%
versicolor_np = iris1.iloc[50:100,:-1].to_numpy()

# %%
plt.scatter(setosa_np[:,0], setosa_np[:,1], s = 20*setosa_np[:,2], c=setosa_np[:,3],cmap = 'YlGn',marker='x')
plt.scatter(versicolor_np[:,0], versicolor_np[:,1], s = 20*versicolor_np[:,2], c=versicolor_np[:,3],cmap = 'YlGn',marker='^')
plt.show()

# %% [markdown]
# # Visualize 3 data

# %%
virginica_np = iris1.iloc[100:,:-1].to_numpy()

# %%
plt.scatter(setosa_np[:,0], setosa_np[:,1], s = 20*setosa_np[:,2], c=setosa_np[:,3],cmap = 'YlGn',marker='x')
plt.scatter(versicolor_np[:,0], versicolor_np[:,1], s = 20*versicolor_np[:,2], c=versicolor_np[:,3],cmap = 'YlGn',marker='^')
plt.scatter(virginica_np[:,0], virginica_np[:,1], s = 20*virginica_np[:,2], c=virginica_np[:,3],cmap = 'YlGn',marker='s')
plt.show()

# %%
matplotlib.rcParams['figure.figsize']=[20,20]

# %%
plt.subplot(1,4,1)
# columns ที่ 1 เป็น X
# columns ที่ 2 เป็น Y
# columns ที่ 3 เป็น S
# columns ที่ 4 เป็น C
plt.scatter(setosa_np[:,0], setosa_np[:,1], s = 20*setosa_np[:,2], c=setosa_np[:,3],cmap = 'cool',marker='x')
plt.scatter(versicolor_np[:,0], versicolor_np[:,1], s = 20*versicolor_np[:,2], c=versicolor_np[:,3],cmap = 'cool',marker='^')
plt.scatter(virginica_np[:,0], virginica_np[:,1], s = 20*virginica_np[:,2], c=virginica_np[:,3],cmap = 'cool',marker='s')
plt.subplot(1,4,2)
# columns ที่ 1 เป็น Y
# columns ที่ 2 เป็น X
# columns ที่ 3 เป็น S
# columns ที่ 4 เป็น C
plt.scatter(setosa_np[:,1], setosa_np[:,0], s = 20*setosa_np[:,2], c=setosa_np[:,3],cmap = 'cool',marker='x')
plt.scatter(versicolor_np[:,1], versicolor_np[:,0], s = 20*versicolor_np[:,2], c=versicolor_np[:,3],cmap = 'cool',marker='^')
plt.scatter(virginica_np[:,1], virginica_np[:,0], s = 20*virginica_np[:,2], c=virginica_np[:,3],cmap = 'cool',marker='s')
plt.subplot(1,4,3)
# columns ที่ 1 เป็น S
# columns ที่ 2 เป็น X
# columns ที่ 3 เป็น Y
# columns ที่ 4 เป็น C
plt.scatter(setosa_np[:,1], setosa_np[:,2], s = 20*setosa_np[:,0], c=setosa_np[:,3],cmap = 'cool',marker='x')
plt.scatter(versicolor_np[:,1], versicolor_np[:,2], s = 20*versicolor_np[:,0], c=versicolor_np[:,3],cmap = 'cool',marker='^')
plt.scatter(virginica_np[:,1], virginica_np[:,2], s = 20*virginica_np[:,0], c=virginica_np[:,3],cmap = 'cool',marker='s')
plt.subplot(1,4,4)
# columns ที่ 1 เป็น C
# columns ที่ 2 เป็น X
# columns ที่ 3 เป็น Y
# columns ที่ 4 เป็น S
plt.scatter(setosa_np[:,1], setosa_np[:,2], s = 20*setosa_np[:,3], c=setosa_np[:,0],cmap = 'cool',marker='x')
plt.scatter(versicolor_np[:,1], versicolor_np[:,2], s = 20*versicolor_np[:,3], c=versicolor_np[:,0],cmap = 'cool',marker='^')
plt.scatter(virginica_np[:,1], virginica_np[:,2], s = 20*virginica_np[:,3], c=virginica_np[:,0],cmap = 'cool',marker='s')
plt.show()
plt.subplot(1,4,1)
# columns ที่ 1 เป็น X
# columns ที่ 2 เป็น Y
# columns ที่ 3 เป็น S
# columns ที่ 4 เป็น C
plt.scatter(setosa_np[:,0], setosa_np[:,1], s = 20*setosa_np[:,2], c=setosa_np[:,3],cmap = 'cool',marker='x')
plt.scatter(versicolor_np[:,0], versicolor_np[:,1], s = 20*versicolor_np[:,2], c=versicolor_np[:,3],cmap = 'cool',marker='^')
plt.scatter(virginica_np[:,0], virginica_np[:,1], s = 20*virginica_np[:,2], c=virginica_np[:,3],cmap = 'cool',marker='s')
plt.subplot(1,4,2)
# columns ที่ 1 เป็น Y
# columns ที่ 2 เป็น X
# columns ที่ 3 เป็น S
# columns ที่ 4 เป็น C
plt.scatter(setosa_np[:,1], setosa_np[:,0], s = 20*setosa_np[:,1], c=setosa_np[:,3],cmap = 'cool',marker='x')
plt.scatter(versicolor_np[:,1], versicolor_np[:,0], s = 20*versicolor_np[:,1], c=versicolor_np[:,3],cmap = 'cool',marker='^')
plt.scatter(virginica_np[:,1], virginica_np[:,0], s = 20*virginica_np[:,1], c=virginica_np[:,3],cmap = 'cool',marker='s')
plt.subplot(1,4,3)
# columns ที่ 1 เป็น X
# columns ที่ 2 เป็น S
# columns ที่ 3 เป็น Y
# columns ที่ 4 เป็น C
plt.scatter(setosa_np[:,0], setosa_np[:,2], s = 20*setosa_np[:,1], c=setosa_np[:,3],cmap = 'cool',marker='x')
plt.scatter(versicolor_np[:,0], versicolor_np[:,2], s = 20*versicolor_np[:,1], c=versicolor_np[:,3],cmap = 'cool',marker='^')
plt.scatter(virginica_np[:,0], virginica_np[:,2], s = 20*virginica_np[:,1], c=virginica_np[:,3],cmap = 'cool',marker='s')
plt.subplot(1,4,4)
# columns ที่ 1 เป็น X
# columns ที่ 2 เป็น C
# columns ที่ 3 เป็น Y
# columns ที่ 4 เป็น S
plt.scatter(setosa_np[:,0], setosa_np[:,2], s = 20*setosa_np[:,3], c=setosa_np[:,1],cmap = 'cool',marker='x')
plt.scatter(versicolor_np[:,0], versicolor_np[:,2], s = 20*versicolor_np[:,3], c=versicolor_np[:,1],cmap = 'cool',marker='^')
plt.scatter(virginica_np[:,0], virginica_np[:,2], s = 20*virginica_np[:,3], c=virginica_np[:,1],cmap = 'cool',marker='s')
plt.show()
